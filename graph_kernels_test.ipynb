# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import gc

# %%
m_18 = np.array([42.95271321599849, 40.81148373204585, 3.873354718711595])
m_19 = np.array([137.67013384188775, 36.0984689386152, 5.170005179633498])
m_20 = np.array([9773.260434352356, 368465.68209435284, 169.08894486730938])
m_21 = np.array([44.56007698309767, 432567.90373036, 10769.378366456967])
m_22 = np.array([120677.39417892482, 12667.945117064664, 275767.0655079218])

# %%
# Crear una figura con 5 subplots

m = [m_18, m_19, m_20, m_21, m_22]
s = ["0.18", "0.19", "0.20", "0.21", "0.22"]

for i in range(5):
    plt.figure(figsize=(5, 3))
    plt.imshow(m[i].reshape(1, -1), cmap='viridis', aspect='auto')
    plt.title(r"$\sigma$ = " + s[i])
    plt.colorbar()
    plt.xticks([])
    plt.yticks([])
    plt.show()
