# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime
plt.rcParams['figure.dpi'] = 200

# %%
def which_day_is_it(date:str)->str:
    """This functions receives a date in the format 'YYYY-MM-DD' and returns the day of the week in Spanish."""
    days = {'Monday':'Lunes', 'Tuesday':'Martes', 'Wednesday':'Miércoles', 'Thursday':'Jueves', 'Friday':'Viernes', 'Saturday':'Sábado', 'Sunday':'Domingo'}
    day = datetime.datetime.strptime(date, '%Y-%m-%d').strftime('%A')
    return days[day]

# %%
dates = pd.read_csv('/Users/antoniomendez/Desktop/Tesis/thesis/vector_files/mixed_wed_sun/dates_2024_ws.csv')
dates.head()
# Out:
#         dates
# 0  2024-09-01
# 1  2024-09-04
# 2  2024-09-08
# 3  2024-09-11
# 4  2024-09-15

# %%
k1 = np.load('/Users/antoniomendez/Desktop/Tesis/thesis/vector_files/mixed_wed_sun/results_clustering_mibici_2/kernel_matrix.npy')
plt.imshow(k1)
plt.colorbar()
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/miercoles-domingos/mk_mibici1.pdf', bbox_inches='tight')

# %%
k2 = np.load('/Users/antoniomendez/Desktop/Tesis/thesis/vector_files/mixed_wed_sun/results_clustering_mibici_3/kernel_matrix.npy')
plt.imshow(k2)
plt.colorbar()
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/miercoles-domingos/mk_mibici2.pdf', bbox_inches='tight')

# %%
k3 = np.load('/Users/antoniomendez/Desktop/Tesis/thesis/vector_files/mixed_wed_sun/results_clustering_eco_2/kernel_matrix.npy')
plt.imshow(k3)
plt.colorbar()
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/miercoles-domingos/mk_eco1.pdf', bbox_inches='tight')

# %%
k4 = np.load('/Users/antoniomendez/Desktop/Tesis/thesis/vector_files/mixed_wed_sun/results_clustering_eco_3/kernel_matrix.npy')
plt.imshow(k4)
plt.colorbar()
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/miercoles-domingos/mk_eco2.pdf', bbox_inches='tight')

# %%
dates = pd.read_csv('vector_files/vacation/dates_24_apr_jun.csv')
dates.head()
# Out:
#         dates
# 0  2024-03-25
# 1  2024-03-26
# 2  2024-03-27
# 3  2024-03-28
# 4  2024-03-29

# %%
k1 = np.load('vector_files/vacation/results_clustering_mibici_2/kernel_matrix.npy')
plt.imshow(k1)
plt.colorbar()
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/vacation/mk_mibici1.pdf', bbox_inches='tight')

# %%
k2 = np.load('/Users/antoniomendez/Desktop/Tesis/thesis/vector_files/vacation/results_clustering_mibici_3/kernel_matrix.npy')
plt.imshow(k2)
plt.colorbar()
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/vacation/mk_mibici2.pdf', bbox_inches='tight')

# %%
k3 = np.load('/Users/antoniomendez/Desktop/Tesis/thesis/vector_files/vacation/results_clustering_eco_2/kernel_matrix.npy')
plt.imshow(k3)
plt.colorbar()
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/vacation/mk_eco1.pdf', bbox_inches='tight')

# %%
k4 = np.load('/Users/antoniomendez/Desktop/Tesis/thesis/vector_files/vacation/results_clustering_eco_3/kernel_matrix.npy')
plt.imshow(k4)
plt.colorbar()
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates)), labels=dates['dates'][::], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/vacation/mk_eco2.pdf', bbox_inches='tight')

# %%
dates = pd.read_csv('vector_files/pandemic_init/results_clustering_eco_1/dates.csv')
dates.head()
# Out:
#          date
# 0  2020-02-20
# 1  2020-02-21
# 2  2020-02-22
# 3  2020-02-23
# 4  2020-02-24

# %%
dates.tail()
# Out:
#           date
# 56  2020-04-16
# 57  2020-04-17
# 58  2020-04-18
# 59  2020-04-19
# 60  2020-04-20

# %%
k1 = np.load('vector_files/pandemic_init/results_clustering_eco_2/kernel_matrix.npy')
plt.imshow(k1)
plt.colorbar()
steps = 2
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['date'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['date'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/pandemic_init/mk_eco1.pdf', bbox_inches='tight')

# %%
k2 = np.load('vector_files/pandemic_init/results_clustering_eco_3/kernel_matrix.npy')
plt.imshow(k2)
plt.colorbar()
steps = 2
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['date'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['date'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/pandemic_init/mk_eco2.pdf', bbox_inches='tight')

# %%
k3 = np.load('vector_files/pandemic_init/results_clustering_mibici_2/kernel_matrix.npy')
plt.imshow(k3)
plt.colorbar()
steps = 2
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['date'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['date'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/pandemic_init/mk_mibici1.pdf', bbox_inches='tight')

# %%
k4 = np.load('vector_files/pandemic_init/results_clustering_mibici_3/kernel_matrix.npy')
plt.imshow(k4)
plt.colorbar()
steps = 2
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['date'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['date'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/pandemic_init/mk_mibici2.pdf', bbox_inches='tight')

# %%
dates = pd.read_csv('vector_files/oct_24/results_clustering_eco_2/dates.csv')
dates.head()
# Out:
#         dates
# 0  2024-10-01
# 1  2024-10-02
# 2  2024-10-03
# 3  2024-10-04
# 4  2024-10-05

# %%
k1 = np.load('vector_files/oct_24/results_clustering_eco_2/kernel_matrix.npy')
plt.imshow(k1)
plt.colorbar()
steps = 1
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/oct_24/mk_eco1.pdf', bbox_inches='tight')

# %%
k2 = np.load('vector_files/oct_24/results_clustering_eco_3/kernel_matrix.npy')
plt.imshow(k2)
plt.colorbar()
steps = 1
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/oct_24/mk_eco2.pdf', bbox_inches='tight')

# %%
k3 = np.load('vector_files/oct_24/results_clustering_mibici_2/kernel_matrix.npy')
plt.imshow(k3)
plt.colorbar()
steps = 1
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/oct_24/mk_mibici1.pdf', bbox_inches='tight')

# %%
k4 = np.load('vector_files/oct_24/results_clustering_mibici_3/kernel_matrix.npy')
plt.imshow(k4)
plt.colorbar()
steps = 1
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/oct_24/mk_mibici2.pdf', bbox_inches='tight')

# %%
dates = pd.read_csv('vector_files/oct_24_no_weekends/dates_24_oct_no_weekends.csv')
dates.head()
# Out:
#         dates
# 0  2024-10-01
# 1  2024-10-02
# 2  2024-10-03
# 3  2024-10-04
# 4  2024-10-07

# %%
k1 = np.load('vector_files/oct_24_no_weekends/results_clustering_eco_2/kernel_matrix.npy')
plt.imshow(k1)
plt.colorbar()
steps = 1
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/oct_24_noweekend/mk_eco1.pdf', bbox_inches='tight')

# %%
k2 = np.load('vector_files/oct_24_no_weekends/results_clustering_eco_3/kernel_matrix.npy')
plt.imshow(k2)
plt.colorbar()
steps = 1
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/oct_24_noweekend/mk_eco2.pdf', bbox_inches='tight')

# %%
k3 = np.load('vector_files/oct_24_no_weekends/results_clustering_mibici_2/kernel_matrix.npy')
plt.imshow(k3)
plt.colorbar()
steps = 1
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/oct_24_noweekend/mk_mibici1.pdf', bbox_inches='tight')

# %%
k4 = np.load('vector_files/oct_24_no_weekends/results_clustering_mibici_3/kernel_matrix.npy')
plt.imshow(k4)
plt.colorbar()
steps = 1
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/oct_24_noweekend/mk_mibici2.pdf', bbox_inches='tight')

# %%
dates = pd.read_csv('vector_files/sep_22/dates_22_sep.csv')
dates.head()
# Out:
#         dates
# 0  2022-09-05
# 1  2022-09-06
# 2  2022-09-07
# 3  2022-09-08
# 4  2022-09-09

# %%
dates.tail()
# Out:
#          dates
# 23  2022-09-28
# 24  2022-09-29
# 25  2022-09-30
# 26  2022-10-01
# 27  2022-10-02

# %%
k1 = np.load('vector_files/sep_22/results_clustering_eco_2/kernel_matrix.npy')
plt.imshow(k1)
plt.colorbar()
steps = 1
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/sep_22/mk_eco1.pdf', bbox_inches='tight')

# %%
k2 = np.load('vector_files/sep_22/results_clustering_eco_3/kernel_matrix.npy')
plt.imshow(k2)
plt.colorbar()
steps = 1
plt.title('Matriz de kernel')
plt.xticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], rotation=90, size=8)
plt.yticks(ticks=np.arange(0, len(dates), steps), labels=dates['dates'][::steps], size=8, rotation=0)
plt.tight_layout()
plt.savefig('/Users/antoniomendez/Desktop/Tesis_script/img/kernels_clustering/sep_22/mk_eco2.pdf', bbox_inches='tight')

# %%
dates_array = [f'2024-10-{i:02}' for i in sorted([11, 25, 16, 18, 31, 2, 7, 10, 28, 9, 23])]
[f'{date}-{which_day_is_it(date)}' for date in dates_array]
# Out:
# ['2024-10-02-Miércoles',
#  '2024-10-07-Lunes',
#  '2024-10-09-Miércoles',
#  '2024-10-10-Jueves',
#  '2024-10-11-Viernes',
#  '2024-10-16-Miércoles',
#  '2024-10-18-Viernes',
#  '2024-10-23-Miércoles',
#  '2024-10-25-Viernes',
#  '2024-10-28-Lunes',
#  '2024-10-31-Jueves']

# %%
dates_array = [f'2024-10-{i:02}' for i in sorted([30, 3, 4, 14, 29, 8, 15, 17, 22, 24])]
[f'{date}-{which_day_is_it(date)}' for date in dates_array]
# Out:
# ['2024-10-03-Jueves',
#  '2024-10-04-Viernes',
#  '2024-10-08-Martes',
#  '2024-10-14-Lunes',
#  '2024-10-15-Martes',
#  '2024-10-17-Jueves',
#  '2024-10-22-Martes',
#  '2024-10-24-Jueves',
#  '2024-10-29-Martes',
#  '2024-10-30-Miércoles']

# %%
dates_array = [f'2024-10-{i:02}' for i in sorted([20, 13, 1, 19, 21, 5, 12])]
[f'{date}-{which_day_is_it(date)}' for date in dates_array]
# Out:
# ['2024-10-01-Martes',
#  '2024-10-05-Sábado',
#  '2024-10-12-Sábado',
#  '2024-10-13-Domingo',
#  '2024-10-19-Sábado',
#  '2024-10-20-Domingo',
#  '2024-10-21-Lunes']

# %%
dates_array = [f'2024-10-{i:02}' for i in sorted([6, 20, 26, 27])]
[f'{date}-{which_day_is_it(date)}' for date in dates_array]
# Out:
# ['2024-10-06-Domingo',
#  '2024-10-20-Domingo',
#  '2024-10-26-Sábado',
#  '2024-10-27-Domingo']
